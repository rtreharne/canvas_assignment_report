# %%
"""
This script imports necessary modules and sets up the environment for generating a Canvas assignment report.

It uses the canvasapi module to interact with the Canvas LMS.
"""

from canvasapi import Canvas
from config import *
import datetime
import csv
import tqdm
import pandas as pd

# %%
"""
This code retrieves submissions and rubric information for a specific assignment in Canvas.
"""

canvas = Canvas(CANVAS_URL, CANVAS_TOKEN)
course = canvas.get_course(course_id)
assignment = course.get_assignment(assignment_id)

submissions = [x for x in assignment.get_submissions(include=["user",
                                                              "submission_comments",
                                                              "rubric_assessment"]
                                                    )]
rubric = assignment.rubric

rubric_rating_headers = [f"RATING_{x['description']}" for x in rubric]
rubric_score_headers = [f"SCORE_{x['description']}" for x in rubric]

header_list = [
    "last_name",
    "first_name",
    "sis_user_id",
    "submitted_at",
    "seconds_late",
    "status",
    "posted_at",
    "score",
    "grader",
    "comments"]

header_list += rubric_rating_headers + rubric_score_headers

# %%
def get_rubric_rating(rubric, rubric_assessment):
    """
    Retrieves the descriptions of the ratings for each rubric item in the rubric assessment.

    Parameters:
    rubric (list): A list of rubric items.
    rubric_assessment (dict): A dictionary containing the rubric assessment data.

    Returns:
    list: A list of rating descriptions for each rubric item in the rubric assessment.
    """
    ratings_list = []
    rubric_flag = False
    for item in rubric:
        rating_id = rubric_assessment[item["id"]]["rating_id"]
        for ratings in item["ratings"]:
            if ratings["id"] == rating_id:
                if ratings["description"]:
                    ratings_list.append(ratings["description"])
                    rubric_flag = True
                else:
                    ratings_list.append("")
        if rubric_flag:
            rubric_flag = False
        else:
            ratings_list.append("")
            
    return ratings_list

def get_rubric_score(rubric, rubric_assessment):
    """
    Calculates the score for each rubric item based on the rubric assessment.

    Parameters:
    rubric (list): The rubric containing the criteria and ratings.
    rubric_assessment (dict): The rubric assessment containing the rating for each rubric item.

    Returns:
    list: A list of scores for each rubric item.
    """
    ratings_list = []
    for item in rubric:
        rating_id = rubric_assessment[item["id"]]["rating_id"]
        for ratings in item["ratings"]:
            if ratings["id"] == rating_id:
                    ratings_list.append(ratings["points"])
        
    return ratings_list

def build_submission_string(header_list, submission):
    """
    Builds a row of data for a submission in a Canvas assignment report.

    Args:
        submission (Submission): The submission object representing a student's submission.

    Returns:
        list: A list containing the row of data for the submission, including student information,
              submission details, grading information, and rubric ratings and scores.
    """
    
    sortable_name = f'{submission.user["sortable_name"]}'
    last_name, first_name = sortable_name.split(", ")
    sis_user_id = submission.user["sis_user_id"]
    submitted_at = submission.submitted_at
    seconds_late = submission.seconds_late
    status = submission.workflow_state
    posted_at = submission.posted_at
    score = submission.score

    try:
        grader = canvas.get_user(submission.grader_id).sortable_name
    except:
        grader = ""
    
    try:
        rubric_assessment = submission.rubric_assessment
    except:
        rubric_assessment = ""
        
    comments = ", ".join([f"{x["author_name"]} - {x["comment"]}" for x in submission.submission_comments])

    if rubric_assessment:
        rubric_rating = get_rubric_rating(rubric, rubric_assessment)
        rubric_score = get_rubric_score(rubric, rubric_assessment)
    else:
        rubric_rating = [""]*len(rubric)
        rubric_score = [""]*len(rubric)

    values = [
        last_name,
        first_name,
        sis_user_id,
        submitted_at,
        seconds_late,
        status,
        posted_at,
        score,
        grader,
        comments
    ]

    values += rubric_rating + rubric_score

    row = {}

    for header, value in zip(header_list, values):
        row[header] = value
        
    return row

# %%
import datetime
import tqdm

filename = f"{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}_{course_id}_{assignment_id}.xlsx"

data = []
for submission in tqdm.tqdm(submissions[:10], desc="Writing submissions to Excel file"):
    data.append(build_submission_string(header_list, submission))

df = pd.DataFrame(data)
df.to_excel(filename, index=False)
# Out:
# Writing submissions to Excel file: 100%|██████████| 10/10 [00:00<00:00, 15.16it/s]

# %%
data
# Out:
# [['last_name',
#   'first_name',
#   'sis_user_id',
#   'submitted_at',
#   'seconds_late',
#   'status',
#   'posted_at',
#   'score',
#   'grader',
#   'RATING_Knowledge and Comprehension of Background - 30 %',
#   'RATING_Handling of Literature - 20 %',
#   'RATING_Aims and Approach - 20 %',
#   'RATING_Structure and Organisation - 10 %',
#   'RATING_Language - 10 %',
#   'RATING_Presentation and Layout - 10 %',
#   'RATING_Academic Integrity',
#   'SCORE_Knowledge and Comprehension of Background - 30 %',
#   'SCORE_Handling of Literature - 20 %',
#   'SCORE_Aims and Approach - 20 %',
#   'SCORE_Structure and Organisation - 10 %',
#   'SCORE_Language - 10 %',
#   'SCORE_Presentation and Layout - 10 %',
#   'SCORE_Academic Integrity',
#   'rubric_comments'],
#  ['Abdulmalik',
#   'Nadia',
#   '201279226hlnharoo',
#   None,
#   4121415,
#   'unsubmitted',
#   None,
#   None,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Bashagha',
#   'Ali',
#   '201428151hlabasha',
#   '2024-01-08T23:48:16Z',
#   0,
#   'graded',
#   '2024-02-13T13:44:29Z',
#   57.0,
#   'Larsen, Carl',
#   '2.2',
#   '2.2',
#   '2.2',
#   '2.1',
#   '1 No integrity issues',
#   11.0,
#   11.0,
#   5.5,
#   6.5,
#   0.0,
#   "Carl Larsen - Ok Ali, I have left comments within your text so please address these. There's is lots of good evidence of understanding the theory and salient literature but your lack of structure in places and tendency to tell the reader what you plan for your study, before telling us about the literature meant that you don't really provide a sound justification for why your study is interesting/important - a careful restructure, which I recall advising on your draft, is required. Your writing has improved post draft but in your new sections avoid the wordy, journalistic phrasing - keep sentences short and factual. You covered a lot of great literature but largely avoided telling the reader about species specific examples - please address this. Proving the detail of studies, eg, what species, how it was affecting etc will allow you to formulate testable hypotheses and make your discussion flow better. Be careful you understand what you mean by time budgets - we are not planning on generating these - ie. working out the percentage time birds engage in different activities - actually very difficult. You are focussing on behavioural responses to disturbance. Nearly everything is here, just needs a repackage and a bit of rewrite. Well done. CL"],
#  ['Barlow',
#   'Zoe',
#   '201393653hlzbarlo',
#   '2024-01-07T15:56:39Z',
#   0,
#   'graded',
#   '2024-02-13T13:44:29Z',
#   66.0,
#   'Gleave, Terry',
#   '2.1',
#   '2.1',
#   '2.1',
#   '2.1',
#   '2.1',
#   'First',
#   '1 No integrity issues',
#   19.5,
#   13.0,
#   13.0,
#   6.5,
#   6.5,
#   7.5,
#   0.0,
#   ''],
#  ['Carre',
#   'Matt',
#   '201393856hlmcarre',
#   '2024-01-07T13:54:24Z',
#   0,
#   'graded',
#   '2024-02-13T13:44:29Z',
#   71.0,
#   'Verspoor, Rudi',
#   'First',
#   'First',
#   '2.1',
#   'First',
#   '2.1',
#   '2.1',
#   '1 No integrity issues',
#   22.5,
#   15.0,
#   13.0,
#   7.5,
#   6.5,
#   6.5,
#   0.0,
#   'Rudi Verspoor - This is well structured, conscise and on topic for the most part.  Ocassional points are highlighted in the text where language chosen, or emphasis could be better.  Overall the proposal shows your understanding is already advanced in the project.  Visualisations are neat and well executed.  Aims and approaches are suitable, considered, and stand you in very good stead for successfully advancing with this project.\n\nComments are scattered througout to encourage and make you further consider there are always imrpovement.'],
#  ['Buxton',
#   'Andrew',
#   '201142698hlabuxt3',
#   '2024-01-08T16:41:29Z',
#   0,
#   'graded',
#   '2024-02-13T13:44:29Z',
#   40.0,
#   'Isanejad, Masoud',
#   '2.2',
#   '2.2',
#   '2.2',
#   '2.2',
#   '2.2',
#   '2.2',
#   'Category B - poor academic practice',
#   16.5,
#   11.0,
#   11.0,
#   5.5,
#   5.5,
#   5.5,
#   0.0,
#   'Masoud Isanejad - Very interesting topic. One major thing that was lacking is the citations, where are the cited references?, Masoud Isanejad - the sentences read at the moment very descriptive like one could read on a webpage or news Chanel- we expect to see scientific language and reading that student have delved with the literature on the topic,, Masoud Isanejad - it seems that your aim was to explain the importance of gut in human- if yes please use subheading for each paragraph: for example Gut and Brain, Gut and hormonal activitis, Masoud Isanejad - in this state I need to reassign the assignment- please read this example and see how they strutted their work:https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4425030/\n\nin the first paragraph already make clear what is the aim of the work, it seems that you want to link gut to several human system and diet- I suggest first to make a table of content which will help you to add pertinent content for each heading, for example you can have a heading on role of gut in satiety and then explain this with relevant studies from ligature and citations and then move to next section for example role of Gut in Insulin activity., Masoud Isanejad - Academic integrity: there are no citations in the text- the list of references need to be corresponding to a number or name of author using Harvard or Vancouver system in the text and in the correct location']]

# %%
build_submission_string(submission)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 build_submission_string(submission)
#
# Cell In[118], line 60, in build_submission_string(submission)
#      46     rubric_score = ""
#      48 row = [
#      49     last_name,
#      50     first_name,
#    (...)
#      57     grader,
#      58 ]
# ---> 60 row += rubric_rating + rubric_score + [comments]
#      62 return row
#
# TypeError: can only concatenate str (not "list") to str
